# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
#reading the data using pandas read_csv method and printing the data
data=pd.read_csv("titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Seeing the top 5 values using head() method
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#overviewing the data using describe method in pandas
data.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>

# %%
#cheching the data types using dtype method in pandas
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Data Cleaning

# %%
#checking for missing values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#filling the missing values in Age column
data['Age'].fillna(data['Age'].median(), inplace=True)
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_3444\1142369532.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(data['Age'].median(), inplace=True)

# %%
#filling the missing values in cabin column
data['Cabin']=data['Cabin'].fillna('Unknown')

# %%
#imputing the missing values in Embarked column
data['Embarked'].fillna(data['Embarked'].mode()[0],inplace=True)
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_3444\3970910478.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Embarked'].fillna(data['Embarked'].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#remove duplicates
data.drop_duplicates(inplace=True)

# %%
# Convert categorical variables to appropriate data types
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
categorical_columns = ['Sex', 'Embarked', 'Pclass']
for column in categorical_columns:
    data[column] = data[column].astype('category')

# %%
data.dtypes
# Out:
# PassengerId       int64
# Survived          int64
# Pclass         category
# Name             object
# Sex            category
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked       category
# dtype: object

# %% [markdown]
# # Univariate Analysis

# %%
#no of people who survived(1) and who died(0)
survival_count=data['Survived'].value_counts()
survival_count
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(data=data, x='Survived')
plt.title('Survival Count')
plt.show()

# %%
sns.countplot(data=data, x='Pclass')
plt.title('Passenger Class Count')
plt.show()

# %%
#gender count
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))

# Calculate gender distribution
gender_counts = data['Sex'].value_counts()

# Define visual elements
colors = ['#ff9888', '#67b3ff']
explode = (0.1, 0)  # Make first slice (male) stand out

plt.pie(gender_counts, 
        explode=explode,
        labels=gender_counts.index,
        colors=colors,
        autopct='%1.1f%%',
        shadow=True,
        startangle=90)

plt.title('Distribution of Gender', pad=20, size=12)
plt.axis('equal')
plt.show()

# %%
# Numerical Features
# Plot Age Distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Age', kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Plot Fare Distribution 
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Fare', kde=True)
plt.title('Distribution of Fare')
plt.xlabel('Fare')
plt.ylabel('Count') 
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
#count of male and female who survived and who didnt survive
survival_count = data.groupby(['Sex', 'Survived']).size().unstack(fill_value=0)
survival_count
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_3444\293044534.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_count = data.groupby(['Sex', 'Survived']).size().unstack(fill_value=0)
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
# Calculate the percentage of survivors for each gender
male_survival_percentage = (survival_count.loc['male', 1] / survival_count.loc['male'].sum()) * 100
female_survival_percentage = (survival_count.loc['female', 1] / survival_count.loc['female'].sum()) * 100
print(male_survival_percentage)
print(female_survival_percentage)
# Out:
# 18.890814558058924
# 74.20382165605095

# %%
# Survival by Gender
plt.figure(figsize=(10, 5))
sns.barplot(data=data, x='Sex', y='Survived')
plt.title('Survival Rate by Gender')
plt.show()

# %%
# Survival by Class
plt.figure(figsize=(10, 5))
sns.barplot(data=data, x='Pclass', y='Survived')
plt.title('Survival Rate by Passenger Class')
plt.show()

# %%
# Age vs Fare
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Age', y='Fare', hue='Survived')
plt.title('Age vs Fare by Survival Status')
plt.show()

# %%
# 1. Age Distribution by Survival
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data, x='Age', hue='Survived', fill=True)
plt.title('Age Distribution by Survival Status')
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend(labels=['Not Survived', 'Survived'])
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
# Group by Pclass and Sex, then calculate the mean survival rate
survival_df = data.groupby(['Pclass', 'Sex'])['Survived'].mean().reset_index()
# Rename the columns for better readability
survival_df.columns = ['Class', 'Gender', 'Survival Rate']
survival_df
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_3444\2189895395.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_df = data.groupby(['Pclass', 'Sex'])['Survived'].mean().reset_index()
#   Class  Gender  Survival Rate
# 0     1  female       0.968085
# 1     1    male       0.368852
# 2     2  female       0.921053
# 3     2    male       0.157407
# 4     3  female       0.500000
# 5     3    male       0.135447

# %%
# Survival by Gender and Class
plt.figure(figsize=(12, 6))
sns.barplot(data=data, x='Pclass', y='Survived', hue='Sex')
plt.title('Survival Rate by Class and Gender')
plt.show()

# %%
# Correlation Matrix
numerical_cols = ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
correlation_matrix = data[numerical_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
# Extract titles from names
data['Title'] = data['Name'].str.extract(' ([A-Za-z]+)\.')
data.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\prana\AppData\Local\Temp\ipykernel_3444\94670648.py:2: SyntaxWarning: invalid escape sequence '\.'
#   data['Title'] = data['Name'].str.extract(' ([A-Za-z]+)\.')
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked Title
# 0      0         A/5 21171   7.2500  Unknown        S    Mr
# 1      0          PC 17599  71.2833      C85        C   Mrs
# 2      0  STON/O2. 3101282   7.9250  Unknown        S  Miss
# 3      0            113803  53.1000     C123        S   Mrs
# 4      0            373450   8.0500  Unknown        S    Mr

# %%
# Create fare ranges
data['FareRange'] = pd.qcut(data['Fare'], q=4, labels=['Low', 'Medium', 'High', 'Very High'])
data.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked Title  FareRange
# 0      0         A/5 21171   7.2500  Unknown        S    Mr        Low
# 1      0          PC 17599  71.2833      C85        C   Mrs  Very High
# 2      0  STON/O2. 3101282   7.9250  Unknown        S  Miss     Medium
# 3      0            113803  53.1000     C123        S   Mrs  Very High
# 4      0            373450   8.0500  Unknown        S    Mr     Medium

# %%
# Create FamilySize feature
data['FamilySize'] = data['SibSp'] + data['Parch'] + 1
data.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked Title  FareRange  \
# 0      0         A/5 21171   7.2500  Unknown        S    Mr        Low
# 1      0          PC 17599  71.2833      C85        C   Mrs  Very High
# 2      0  STON/O2. 3101282   7.9250  Unknown        S  Miss     Medium
# 3      0            113803  53.1000     C123        S   Mrs  Very High
# 4      0            373450   8.0500  Unknown        S    Mr     Medium
#
#    FamilySize
# 0           2
# 1           2
# 2           1
# 3           2
# 4           1

# %%
# Create the count plot
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='Title', hue='Survived')

# Rotate the x-axis labels
plt.xticks(rotation=45, ha='right')

# Set the title
plt.title('Survival by Title')

# Show the plot
plt.show()

# %%
sns.countplot(data=data, x='FareRange', hue='Survived')
plt.title('Survival by Fare Range')
plt.show()

# %%
sns.barplot(data=data, x='FamilySize', y='Survived')
plt.title('Survival by Family Size')
plt.show()

# %%
# Calculate key statistics
survival_rate = data['Survived'].mean() * 100
female_survival_rate = data[data['Sex'] == 'female']['Survived'].mean() * 100
male_survival_rate = data[data['Sex'] == 'male']['Survived'].mean() * 100
first_class_survival_rate = data[data['Pclass'] == 1]['Survived'].mean() * 100
third_class_survival_rate = data[data['Pclass'] == 3]['Survived'].mean() * 100
average_age = data['Age'].mean()
average_fare = data['Fare'].mean()


print("\nKey Insights:")
print(f"Overall Survival Rate: {survival_rate:.2f}%")
print(f"Female Survival Rate: {female_survival_rate:.2f}%")
print(f"Male Survival Rate: {male_survival_rate:.2f}%")
print(f"First Class Survival Rate: {first_class_survival_rate:.2f}%")
print(f"Third Class Survival Rate: {third_class_survival_rate:.2f}%")
print(f"Average Age: {average_age:.2f}")
print(f"Average Fare: {average_fare:.2f}")
# Out:
# Key Insights:
# Overall Survival Rate: 38.38%
# Female Survival Rate: 74.20%
# Male Survival Rate: 18.89%
# First Class Survival Rate: 62.96%
# Third Class Survival Rate: 24.24%
# Average Age: 29.36
# Average Fare: 32.20

# %% [markdown]
# # Insights and Conclusions

# %% [markdown]
# 1-SURVIVAL RATES:
#
# a-Approximately 38% of passengers survived the disaster. b-Females had a significantly higher survival rate compared to males (~74% of females survived, while only ~19% of males survived).
#
# 2-PASSENGER CLASS (Pclass):
#
# a-Passengers in 1st class had the highest survival rate (~63%), followed by 2nd class (~47%), and 3rd class (~24%). b-The likelihood of survival decreases with a lower passenger class.
#
# 3-AGE DISTRIBUTION
#
# a-Most passengers were young adults between 20-40 years. b-Children under 10 had a relatively higher survival rate, indicating priority given to children during evacuation.
#
# 4-GENDER AND CLASS INTERATION:
#
# a-Females in 1st and 2nd class had the highest survival rates (~97% and ~92%, respectively). b-Males in 3rd class had the lowest survival rate (~14%).
#
# 5-FARE
#
# a-Higher fares were strongly correlated with higher survival rates. Passengers who paid higher fares (1st class) had better access to lifeboats and safety.
#
# 6-FAMILY SIZE
#
# a-Passengers with a family size of 2-4 (e.g., small families) had higher survival rates. Those traveling alone (family size = 1) or in large families (family size > 4) had lower survival rates.
